# %% [markdown]
# <a href="https://colab.research.google.com/github/anhtin18/SGU26_Ml/blob/main/pythonbasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# basic python

# %%
x = 3.1
type(x)
# Out:
# float

# %%
y = 6

type(y)
# Out:
# int

# %%
x*y
# Out:
# 18.6

# %%
x = [14,5,6,6]
type(x)
# Out:
# list

# %%
print(x[:2])
# Out:
# [14, 5]

# %%
x.append(7)
x
# Out:
# [14, 5, 6, 6, 7]

# %%
set(x)
# Out:
# {5, 6, 7, 14}

# %%
for z in x:
    print(z)
    # in python, the indentation matters!
# Out:
# 14
# 5
# 6
# 6
# 7

# %%
# a dictionary (like java's Map)
mymap = {}
mymap['a'] = x
mymap['b'] = y
mymap
# Out:
# {'a': [14, 5, 6, 6, 7], 'b': 6}

# %%
for k,v in mymap.items():
    print('key: ',k, '\t val: ', v)
# Out:
# key:  a 	 val:  [14, 5, 6, 6, 7]
# key:  b 	 val:  6
